# %%
#Let's start with importing necessary libraries

import pandas as pd 
import numpy as np 
from sklearn.preprocessing import StandardScaler 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score, precision_score
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('dataset.csv')

# %%
data
# Out:
#       Marital status  Application mode  Application order  Course  \
# 0                  1                 8                  5       2
# 1                  1                 6                  1      11
# 2                  1                 1                  5       5
# 3                  1                 8                  2      15
# 4                  2                12                  1       3
# ...              ...               ...                ...     ...
# 4419               1                 1                  6      15
# 4420               1                 1                  2      15
# 4421               1                 1                  1      12
# 4422               1                 1                  1       9
# 4423               1                 5                  1      15
#
#       Daytime/evening attendance  Previous qualification  Nacionality  \
# 0                              1                       1            1
# ...

# %%
data_cat = data.select_dtypes(include=np.object)
data_cat.columns
# Out:
# Index(['Target'], dtype='object')

# %%
data.dtypes
# Out:
# Marital status                                      int64
# Application mode                                    int64
# Application order                                   int64
# Course                                              int64
# Daytime/evening attendance                          int64
# Previous qualification                              int64
# Nacionality                                         int64
# Mother's qualification                              int64
# Father's qualification                              int64
# Mother's occupation                                 int64
# Father's occupation                                 int64
# Displaced                                           int64
# Educational special needs                           int64
# Debtor                                              int64
# Tuition fees up to date                             int64
# Gender                                              int64
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 35 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   int64
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4424 non-null   int64
#  4   Daytime/evening attendance                      4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Nacionality                                     4424 non-null   int64
#  7   Mother's qualification                          4424 non-null   int64
#  8   Father's qualification                          4424 non-null   int64
# ...

# %% [markdown]
# * AS we can see there are 5 columns which has data types is float so we can convert into integer.

# %%
data[['Curricular units 1st sem (grade)', 'Curricular units 2nd sem (grade)', 'Unemployment rate', 'Inflation rate', 'GDP']] = data[['Curricular units 1st sem (grade)', 'Curricular units 2nd sem (grade)', 'Unemployment rate', 'Inflation rate', 'GDP']].astype(np.int64)

# %%
data.dtypes
# Out:
# Marital status                                     int64
# Application mode                                   int64
# Application order                                  int64
# Course                                             int64
# Daytime/evening attendance                         int64
# Previous qualification                             int64
# Nacionality                                        int64
# Mother's qualification                             int64
# Father's qualification                             int64
# Mother's occupation                                int64
# Father's occupation                                int64
# Displaced                                          int64
# Educational special needs                          int64
# Debtor                                             int64
# Tuition fees up to date                            int64
# Gender                                             int64
# ...

# %%
data.columns
# Out:
# Index(['Marital status', 'Application mode', 'Application order', 'Course',
#        'Daytime/evening attendance', 'Previous qualification', 'Nacionality',
#        'Mother's qualification', 'Father's qualification',
#        'Mother's occupation', 'Father's occupation', 'Displaced',
#        'Educational special needs', 'Debtor', 'Tuition fees up to date',
#        'Gender', 'Scholarship holder', 'Age at enrollment', 'International',
#        'Curricular units 1st sem (credited)',
#        'Curricular units 1st sem (enrolled)',
#        'Curricular units 1st sem (evaluations)',
#        'Curricular units 1st sem (approved)',
#        'Curricular units 1st sem (grade)',
#        'Curricular units 1st sem (without evaluations)',
#        'Curricular units 2nd sem (credited)',
#        'Curricular units 2nd sem (enrolled)',
#        'Curricular units 2nd sem (evaluations)',
#        'Curricular units 2nd sem (approved)',
#        'Curricular units 2nd sem (grade)',
# ...

# %% [markdown]
# ### Data Preparation

# %%
data.rename(columns={'Nacionality':'Nationality'}, inplace=True)

# %%
missing_values = data.isna().sum()
missing_values
# Out:
# Marital status                                    0
# Application mode                                  0
# Application order                                 0
# Course                                            0
# Daytime/evening attendance                        0
# Previous qualification                            0
# Nationality                                       0
# Mother's qualification                            0
# Father's qualification                            0
# Mother's occupation                               0
# Father's occupation                               0
# Displaced                                         0
# Educational special needs                         0
# Debtor                                            0
# Tuition fees up to date                           0
# Gender                                            0
# Scholarship holder                                0
# Age at enrollment                                 0
# ...

# %% [markdown]
# ### Scaling Numerical Features

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
data[['Unemployment rate', 'Inflation rate', 'GDP']] = scaler.fit_transform(data[['Unemployment rate', 'Inflation rate', 'GDP']])

# %%
data[['Unemployment rate', 'Inflation rate', 'GDP']]
# Out:
#       Unemployment rate  Inflation rate       GDP
# 0             -0.371751        0.073639  0.584576
# 1              0.727843       -0.890201  0.080254
# 2             -0.371751        0.073639  0.584576
# 3             -0.738282       -0.890201 -1.432713
# 4              0.727843       -0.890201  0.080254
# ...                 ...             ...       ...
# 4419           1.460905        1.037478 -1.937035
# 4420          -0.005220       -0.890201  1.088898
# 4421           0.727843       -0.890201  0.080254
# 4422          -0.738282       -0.890201 -1.432713
# 4423           0.361312        2.001318 -0.424068
#
# [4424 rows x 3 columns]

# %%
data = data.replace({ 'Target' : { 'Dropout' : 0, 'Graduate' : 1, 'Enrolled' : 2 } })

# %%
data
# Out:
#       Marital status  Application mode  Application order  Course  \
# 0                  1                 8                  5       2
# 1                  1                 6                  1      11
# 2                  1                 1                  5       5
# 3                  1                 8                  2      15
# 4                  2                12                  1       3
# ...              ...               ...                ...     ...
# 4419               1                 1                  6      15
# 4420               1                 1                  2      15
# 4421               1                 1                  1      12
# 4422               1                 1                  1       9
# 4423               1                 5                  1      15
#
#       Daytime/evening attendance  Previous qualification  Nationality  \
# 0                              1                       1            1
# ...

# %% [markdown]
# ## 1. Exploratory Data Analysis(Categorical Features)

# %% [markdown]
# ### 1) Visulalizing the total number of students dropout, graduate and enrolled

# %%
v = data['Target'].value_counts()

import plotly.graph_objects as go

labels = ['Graduate', 'Dropout', 'Enrolled']

fig = go.Figure(data=[go.Pie(labels=labels, values=v, pull=[0,0.1, 0.1])])
fig.show()
# Out:
# <div>                            <div id="c5d8a1ab-418a-406c-a11e-67a233b7ec06" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c5d8a1ab-418a-406c-a11e-67a233b7ec06")) {                    Plotly.newPlot(                        "c5d8a1ab-418a-406c-a11e-67a233b7ec06",                        [{"labels":["Graduate","Dropout","Enrolled"],"pull":[0,0.1,0.1],"values":[2209,1421,794],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.77777777
# ...

# %% [markdown]
# * There are 50% of students are Graduate from the college
# * There are 18% of students are enrolled to the college.
# * There are 32% of students are dropout from the college.

# %% [markdown]
# ### 2) Visualizing the total number of students dropout, graduate and enrolled with respect to Course

# %%
sns.set(rc={'figure.figsize':(12, 8)})
sns.countplot(x=data['Course'], hue=data['Target'], data=data)
# Out:
# <AxesSubplot:xlabel='Course', ylabel='count'>

# %% [markdown]
# | Attribute   | Values                              |
# |-------------|------------------------------------|
# | Course      | 1—Biofuel Production Technologies   |
# |             | 2—Animation and Multimedia Design   |
# |             | 3—Social Service (evening attendance)|
# |             | 4—Agronomy                          |
# |             | 5—Communication Design              |
# |             | 6—Veterinary Nursing                |
# |             | 7—Informatics Engineering           |
# |             | 8—Equiniculture                     |
# |             | 9—Management                        |
# |             | 10—Social Service                   |
# |             | 11—Tourism                         |
# |             | 12—Nursing                          |
# |             | 13—Oral Hygiene                    |
# |             | 14—Advertising and Marketing Management|
# |             | 15—Journalism and Communication    |
# |             | 16—Basic Education                  |
# |             | 17—Management (evening attendance)  |

# %% [markdown]
# * As we can observed that the most of the students are graduated in 12th category i.e in <b>(NURSING)</b> and ratio is also much  higher compare to other courses.

# %% [markdown]
# ### 3) Visualizing the total number of students dropout, graduate and enrolled w.r.t Nationality

# %%
sns.set(rc={'figure.figsize':(12, 8)})
sns.countplot(x='Nationality', hue='Target', data=data)
plt.show()

# %% [markdown]
# | Attribute   | Values                   |
# |-------------|-------------------------|
# | Nationality | 1—Portuguese             |
# |             | 2—German                 |
# |             | 3—Spanish                |
# |             | 4—Italian                |
# |             | 5—Dutch                  |
# |             | 6—English                |
# |             | 7—Lithuanian             |
# |             | 8—Angolan                |
# |             | 9—Cape Verdean           |
# |             | 10—Guinean               |
# |             | 11—Mozambican            |
# |             | 12—Santomean             |
# |             | 13—Turkish               |
# |             | 14—Brazilian             |
# |             | 15—Romanian              |
# |             | 16—Moldova (Republic of) |
# |             | 17—Mexican               |
# |             | 18—Ukrainian             |
# |             | 19—Russian               |
# |             | 20—Cuban                 |
# |             | 21—Colombian             |

# %% [markdown]
# * As we can observed that the Nationality of the most students are fall in 1st category i.e is in <b>Portuguese</b>.

# %% [markdown]
# ### 3) Visualizing the total number of students dropout, graduate and enrolled w.r.t attendance

# %%
sns.set(rc={'figure.figsize':(12, 8)})
plt.figure(figsize=(13,7))
sns.countplot(x='Daytime/evening attendance', hue='Target', data=data)
plt.show()

# %% [markdown]
# #### In the above graph, in 'Daytime/evening attendance' axis, 1 --> daytime and 0 --> evening

# %%
data.isnull().sum()
# Out:
# Marital status                                    0
# Application mode                                  0
# Application order                                 0
# Course                                            0
# Daytime/evening attendance                        0
# Previous qualification                            0
# Nationality                                       0
# Mother's qualification                            0
# Father's qualification                            0
# Mother's occupation                               0
# Father's occupation                               0
# Displaced                                         0
# Educational special needs                         0
# Debtor                                            0
# Tuition fees up to date                           0
# Gender                                            0
# Scholarship holder                                0
# Age at enrollment                                 0
# ...

# %%
cor = data.corr()
data.corr()["Target"]
# Out:
# Application order                         0.027393
# Daytime/evening attendance                0.066439
# Nationality                               0.009248
# Mother's occupation                       0.077593
# Father's occupation                       0.094916
# Educational special needs                 0.003751
# Tuition fees up to date                   0.342121
# Scholarship holder                        0.114517
# International                             0.015893
# Curricular units 1st sem (enrolled)       0.052020
# Curricular units 1st sem (evaluations)    0.125278
# Curricular units 1st sem (approved)       0.290243
# Curricular units 1st sem (grade)          0.346629
# Curricular units 2nd sem (credited)      -0.002427
# Curricular units 2nd sem (enrolled)       0.060670
# Curricular units 2nd sem (evaluations)    0.194412
# Curricular units 2nd sem (approved)       0.351135
# Curricular units 2nd sem (grade)          0.426441
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(cor, annot = True, cmap = 'BuGn_r',fmt=".2f",annot_kws={"size": 8})
# Out:
# <AxesSubplot:>

# %% [markdown]
# * we will be dropping the columns which are giving negative relation to the target variable by observing through correlation matrix

# %%
data.columns
# Out:
# Index(['Marital status', 'Application mode', 'Application order', 'Course',
#        'Daytime/evening attendance', 'Previous qualification', 'Nationality',
#        'Mother's qualification', 'Father's qualification',
#        'Mother's occupation', 'Father's occupation', 'Displaced',
#        'Educational special needs', 'Debtor', 'Tuition fees up to date',
#        'Gender', 'Scholarship holder', 'Age at enrollment', 'International',
#        'Curricular units 1st sem (credited)',
#        'Curricular units 1st sem (enrolled)',
#        'Curricular units 1st sem (evaluations)',
#        'Curricular units 1st sem (approved)',
#        'Curricular units 1st sem (grade)',
#        'Curricular units 1st sem (without evaluations)',
#        'Curricular units 2nd sem (credited)',
#        'Curricular units 2nd sem (enrolled)',
#        'Curricular units 2nd sem (evaluations)',
#        'Curricular units 2nd sem (approved)',
#        'Curricular units 2nd sem (grade)',
# ...

# %%
data = data.drop(columns=['Application mode', 'Marital status', 'Course', 'Debtor', 'Previous qualification', 'Displaced', 'Father\'s qualification', 'Mother\'s qualification', 'Gender', 'Age at enrollment', 'Curricular units 1st sem (credited)', 'Curricular units 1st sem (without evaluations)', 'Unemployment rate', 'Inflation rate', 'Curricular units 2nd sem (without evaluations)'], axis=1)

# %%
data.shape
# Out:
# (4424, 20)

# %%
data = data[data["Target"] != "Enrolled"]

# %% [markdown]
# ## Model Training

# %% [markdown]
# #### i) Using DecisionTreeClassifier Model

# %%
from sklearn.tree import DecisionTreeClassifier
x = data.drop(columns=['Target'], axis = 1)
y = data.Target

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((3539, 19), (885, 19), (3539,), (885,))

# %%
dt=DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_split=40)
dt.fit(x_train, y_train)
pred = dt.predict(x_test)

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.73      0.74       316
#            1       0.73      0.95      0.82       418
#            2       0.43      0.09      0.14       151
#
#     accuracy                           0.73       885
#    macro avg       0.64      0.59      0.57       885
# weighted avg       0.69      0.73      0.68       885

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
max_depth=[int(x) for x in np.linspace(3,50,20)]
min_samples_split=[5,8,10,12,15,20,30,35,40]
param_grid={'max_depth':max_depth, 'min_samples_split':min_samples_split, 'criterion':['entropy','gini impurtity']}
grid_model = GridSearchCV(dt,param_grid,cv=3)
grid_model.fit(x_train, y_train)
grid_model.best_estimator_
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=12, min_samples_split=35)

# %%
grid_model.best_score_
# Out:
# 0.7456881969302723

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
rf = RandomForestClassifier(n_estimators=100, random_state=42, max_depth=30)
rf.fit(x_train, y_train)
pred = rf.predict(x_test)

from sklearn.metrics import classification_report
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.74      0.77       316
#            1       0.77      0.89      0.83       418
#            2       0.43      0.32      0.37       151
#
#     accuracy                           0.74       885
#    macro avg       0.67      0.65      0.66       885
# weighted avg       0.73      0.74      0.73       885

# %%
# Get feature importances
feature_importances = rf.feature_importances_

# Get column names
columns = x.columns

# Create a DataFrame to hold feature importances
feature_importance_df = pd.DataFrame({'Feature': columns, 'Importance': feature_importances})

# Sort features by importance
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Plot feature importances
plt.figure(figsize=(10, 6))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'])
plt.xlabel('Feature Importance')
plt.title('Feature Importance using Random Forest')
plt.show()

# %%
#predicting using the AdaBoost_Classifier
from sklearn.ensemble import AdaBoostClassifier
model_AdaBoost=AdaBoostClassifier(base_estimator=
                                  DecisionTreeClassifier(random_state=10),
                                  n_estimators=100,
                              random_state=10)

#fit the model on the data and predict the values
model_AdaBoost.fit(x_train,y_train)

pred=model_AdaBoost.predict(x_test)
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.69      0.75       316
#            1       0.79      0.90      0.84       418
#            2       0.46      0.44      0.45       151
#
#     accuracy                           0.74       885
#    macro avg       0.69      0.67      0.68       885
# weighted avg       0.74      0.74      0.74       885

# %%
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
import pandas as pd

# Assuming 'X' is your feature matrix and 'y' is your target variable
# If not, replace 'X' and 'y' with your actual variable names

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Initialize SMOTE
smote = SMOTE(random_state=42)

# Apply SMOTE to the training data
x_train_resampled, y_train_resampled = smote.fit_resample(x_train, y_train)

# Now x_train_resampled and y_train_resampled contain the resampled data
# You can use these for training your model

# Optionally, you can convert them back to a DataFrame if needed
x_train_resampled = pd.DataFrame(x_train_resampled, columns=x_train.columns)
y_train_resampled = pd.Series(y_train_resampled)

# %%
pip show matplotlib
# Out:
# Name: matplotlib
# Version: 3.5.2
# Summary: Python plotting package
# Home-page: https://matplotlib.org
# Author: John D. Hunter, Michael Droettboom
# Author-email: matplotlib-users@python.org
# License: PSF
# Location: c:\users\mrsag\anaconda3\lib\site-packages
# Requires: cycler, fonttools, kiwisolver, numpy, packaging, pillow, pyparsing, python-dateutil
# Required-by: dabl, missingno, seaborn
# Note: you may need to restart the kernel to use updated packages.
